# %% [markdown]
# # Layer: Gold (Business)
# **Project:** Lean Logistics Data Pipeline
# **Business Domain:** E-commerce (Olist Dataset)
# **Table Name:** `dm_sellers`
#
# ---
# ## 📑 Notebook Information
# | Version | Date | Author | Summary of Changes |
# | :--- | :--- | :--- | :--- |
# | v1.0 | 2026-02-20 | Tássia Marchito | Initial creation: Seller and Geolocation join with metadata. |
# | v1.1 | 2026-02-22 | Tássia Marchito | Optimized spatial aggregation, standardized English metadata, and added DQ validation. |
#
# ---
# ## 🎯 Objectives
# This notebook creates the Seller Dimension by enriching seller data with geographic coordinates.
# * **Data Enrichment:** Joining `tb_sellers` with aggregated `tb_geolocation` to provide spatial context.
# * **Performance & Optimization:** Pre-join aggregation on geolocation to ensure 1:1 cardinality and use of `RELY` constraints for query optimization.
# * **Data Quality & Integrity:** Maintained 1:1 cardinality (3,095 sellers) with **zero duplicate Primary Keys** and a **99.77% Match Rate**.
# * **Standardization:** Enforcing `UPPER` and `TRIM` on geographic strings for reporting consistency.
# * **Governance:** Applying English column comments and discovery tags for Unity Catalog integration.

# %%
from pyspark.sql.functions import col, avg, current_timestamp, upper, trim

# %%
# 1. Configuration
source_sellers = "cat_tm_services_silver.db_logistics.tb_sellers"
source_geo = "cat_tm_services_silver.db_logistics.tb_geolocation"
target_table = "cat_tm_services_gold.db_logistics.dm_sellers"

print(f"🚀 Building {target_table}...")

# 2. Geolocation Preparation (Aggregate to avoid ZIP code duplicates)
# Optimization: Reduces data volume before the join, lowering cluster cost
df_geo_agg = (spark.read.table(source_geo)
    .groupBy("cd_geolocation_zip_code_prefix")
    .agg(
        avg("cd_geolocation_lat").alias("vl_latitude"),
        avg("cd_geolocation_lng").alias("vl_longitude")
    ))

# 3. Seller Enrichment and Transformation
df_sellers = spark.read.table(source_sellers)

dm_sellers = (df_sellers.join(
    df_geo_agg, 
    df_sellers.cd_seller_zip_code_prefix == df_geo_agg.cd_geolocation_zip_code_prefix, 
    "left"
).select(
    col("cd_seller_id"),
    col("cd_seller_zip_code_prefix").alias("cd_zip_code"),
    upper(trim(col("nm_seller_city"))).alias("nm_city"), # Standardizing case
    upper(trim(col("nm_seller_state"))).alias("nm_state"),
    col("vl_latitude"),
    col("vl_longitude")
).withColumn("ts_gold_at", current_timestamp()))

# 4. Table Persistence
(dm_sellers.write.format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(target_table))

# 5. Governance (Unity Catalog Integration)
print(f"📝 Applying metadata and constraints to {target_table}...")

# Table Comments and Tags
spark.sql(f"COMMENT ON TABLE {target_table} IS 'Gold Dimension: Consolidated seller profiles with aggregated spatial coordinates.'")
spark.sql(f"ALTER TABLE {target_table} SET TAGS ('quality' = 'gold', 'domain' = 'logistics', 'type' = 'dimension')")

# Column Documentation (Standardized Dictionary)
column_comments = {
    "cd_seller_id": "Unique identifier for the seller (PK).",
    "cd_zip_code": "Seller zip code prefix.",
    "nm_city": "City name standardized to uppercase.",
    "nm_state": "State abbreviation standardized to uppercase.",
    "vl_latitude": "Average latitude calculated from geolocation master data.",
    "vl_longitude": "Average longitude calculated from geolocation master data.",
    "ts_gold_at": "Processing timestamp for the Gold layer ingestion."
}

for column, comment in column_comments.items():
    spark.sql(f"ALTER TABLE {target_table} ALTER COLUMN {column} COMMENT '{comment}'")

# Constraints (RELY for Optimizer performance)
spark.sql(f"ALTER TABLE {target_table} ALTER COLUMN cd_seller_id SET NOT NULL")
try:
    spark.sql(f"ALTER TABLE {target_table} ADD CONSTRAINT pk_dm_sellers PRIMARY KEY(cd_seller_id) RELY")
except:
    print("⚠️ PK Constraint already exists.")

# %%
# --- Gold Layer Validation: dm_sellers Quality Check ---
print(f"🧐 Validating Data Quality for {target_table}...")

# 1. Duplicate Check
duplicate_count = dm_sellers.groupBy("cd_seller_id").count().filter("count > 1").count()

# 2. Join Integrity Check
silver_count = spark.table(source_sellers).count()
gold_count = dm_sellers.count()

# 3. Match Rate (Sellers with valid coords)
match_rate = (dm_sellers.filter(col("vl_latitude").isNotNull()).count() / gold_count) * 100

print(f"\n📊 Quality Metrics:")
print(f"  - Total Sellers in Silver: {silver_count}")
print(f"  - Total Sellers in Gold: {gold_count}")
print(f"  - Duplicate Primary Keys: {duplicate_count}")
print(f"  - Geolocation Match Rate: {match_rate:.2f}%")

if gold_count == silver_count and duplicate_count == 0:
    print("\n✅ Data Quality Verified: Seller base integrity maintained.")
else:
    print("\n⚠️ Warning: Potential data integrity issue detected.")
