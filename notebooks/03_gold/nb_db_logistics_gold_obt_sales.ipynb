# %% [markdown]
# # Layer: Gold (Business)
# **Project:** Lean Logistics Data Pipeline
# **Business Domain:** E-commerce (Olist Dataset)
# **Table Name:** `obt_sales`
#
# ---
# ## 📑 Notebook Information
# | Version | Date | Author | Summary of Changes |
# | :--- | :--- | :--- | :--- |
# | v1.0 | 2026-02-20 | Tássia Marchito | Initial OBT creation for denormalized BI consumption. |
# | v1.1 | 2026-02-23 | Tássia Marchito | Optimized joins, included Data Quality check, and added Z-Order for query performance. |
#
# ---
# ## 🎯 Objectives
# This notebook creates a flattened, denormalized table (One Big Table) to provide a high-performance experience for BI tools.
# * **Denormalization:** Merging `ft_sales` with all dimensions into a single wide table.
# * **Query Performance:** Implementing `Z-ORDER` on time and location columns to drastically reduce file skipping latency.
# * **Observability:** Final automated validation to ensure the OBT row count perfectly matches the Fact table.

# %%
from pyspark.sql.functions import col, current_timestamp

# %%
from pyspark.sql.functions import col, current_timestamp

# 1. Configuration
gold_db = "cat_tm_services_gold.db_logistics"
target_table = f"{gold_db}.obt_sales"

print(f"🚀 Building OBT: {target_table}...")

# 2. Loading Gold Tables (Using only necessary columns to save memory)
df_fact = spark.read.table(f"{gold_db}.ft_sales")
df_prod = spark.read.table(f"{gold_db}.dm_products").select("cd_product_id", "ds_product_category")
df_cust = spark.read.table(f"{gold_db}.dm_customers").select("cd_customer_id", "nm_city", "nm_state")
df_sell = spark.read.table(f"{gold_db}.dm_sellers").select("cd_seller_id", "nm_city", "nm_state")

# 3. Total Denormalization
# Left joins ensure no sales data is lost even if dimensional data is missing
df_obt = (df_fact
    .join(df_prod, df_fact.id_product == df_prod.cd_product_id, "left")
    .join(df_cust, df_fact.id_customer == df_cust.cd_customer_id, "left")
    .join(df_sell, df_fact.id_seller == df_sell.cd_seller_id, "left")
)

# 4. Final Selection and Alias Standardization
df_obt_final = (df_obt.select(
    # Order & Time
    col("id_order"),
    col("ts_order_purchase"),
    col("ts_order_delivered_customer"),
    col("dt_order_estimated_delivery"),
    # Product
    col("id_product"),
    col("ds_product_category"),
    # Customer (Aliased for clarity)
    col("id_customer"),
    df_cust["nm_city"].alias("nm_customer_city"),
    df_cust["nm_state"].alias("nm_customer_state"),
    # Seller (Aliased for clarity)
    col("id_seller"),
    df_sell["nm_city"].alias("nm_seller_city"),
    df_sell["nm_state"].alias("nm_seller_state"),
    # Metrics
    col("vl_price"),
    col("vl_freight_value"),
    col("vl_total_order"),
    col("vl_review_score"),
    col("nr_days_to_deliver"),
    col("nr_days_delivery_performance")
).withColumn("ts_gold_at", current_timestamp()))

# 5. Writing and Optimization (Z-Order)
# Z-Ordering by purchase date and state for faster BI filtering
(df_obt_final.write.format("delta")
    .mode("overwrite")
    .option("overwriteSchema", "true")
    .saveAsTable(target_table))

print(f"⚡ Optimizing table with Z-Order...")
spark.sql(f"OPTIMIZE {target_table} ZORDER BY (ts_order_purchase, nm_customer_state)")

# 6. Governance
print(f"📝 Applying metadata to {target_table}...")

spark.sql(f"COMMENT ON TABLE {target_table} IS 'Gold OBT: Denormalized sales table for high-performance BI dashboards.'")
spark.sql(f"ALTER TABLE {target_table} SET TAGS ('quality' = 'gold', 'domain' = 'logistics', 'type' = 'obt')")

# Logic to apply comments (Standardized across the pipeline)
comments = {
    "id_order": "Unique order identifier.",
    "ds_product_category": "Product category translated to English.",
    "nm_customer_city": "City of the customer.",
    "vl_total_order": "Revenue: Total amount paid for the order.",
    "nr_days_to_deliver": "Actual delivery lead time in days."
}
for column, comment in comments.items():
    spark.sql(f"ALTER TABLE {target_table} ALTER COLUMN {column} COMMENT '{comment}'")

# %%
# --- OBT Integrity Validation ---
print(f"🧐 Validating OBT Consistency...")

fact_count = df_fact.count()
obt_count = df_obt_final.count()

print(f"  - Fact Table Rows: {fact_count}")
print(f"  - OBT Table Rows: {obt_count}")

if fact_count == obt_count:
    print("\n✅ OBT Verified: No data loss during denormalization.")
else:
    print("\n⚠️ Warning: Row count mismatch detected!")
